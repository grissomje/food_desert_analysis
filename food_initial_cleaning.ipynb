# %%
import pandas as pd
from functools import reduce

# %%
county= pd.read_excel('FoodEnvironmentAtlas.xls', sheet_name='Supplemental Data - County')
access=pd.read_excel('FoodEnvironmentAtlas.xls', sheet_name='ACCESS')
stores=pd.read_excel('FoodEnvironmentAtlas.xls', sheet_name='STORES')
restaurants=pd.read_excel('FoodEnvironmentAtlas.xls', sheet_name='RESTAURANTS')
insecurity=pd.read_excel('FoodEnvironmentAtlas.xls', sheet_name='INSECURITY')
local=pd.read_excel('FoodEnvironmentAtlas.xls', sheet_name='LOCAL')
socioeconomic=pd.read_excel('FoodEnvironmentAtlas.xls', sheet_name='SOCIOECONOMIC')

# %%
#county columns to drop
county_drop=['Population_Estimate_2016','Population_Estimate_2017','Population_Estimate_2018']

county = county.drop(columns=county_drop)

#access columns to drop
access_drop=['LACCESS_CHILD10','LACCESS_CHILD15','LACCESS_CHILD_10_15','PCT_LACCESS_CHILD10','PCT_LACCESS_CHILD15','LACCESS_SENIORS10','LACCESS_SENIORS15','PCH_LACCESS_SENIORS_10_15','PCT_LACCESS_SENIORS10','PCT_LACCESS_SENIORS15','LACCESS_WHITE15','PCT_LACCESS_WHITE15','LACCESS_BLACK15','PCT_LACCESS_BLACK15','LACCESS_HISP15','PCT_LACCESS_HISP15','LACCESS_NHASIAN15','PCT_LACCESS_NHASIAN15','LACCESS_NHNA15','PCT_LACCESS_NHNA15','LACCESS_NHPI15','PCT_LACCESS_NHPI15','LACCESS_MULTIR15','PCT_LACCESS_MULTIR15']

access = access.drop(columns=access_drop)

#store columns to drop
stores_drop=['SNAPS12','SNAPS17','PCH_SNAPS_12_17','SNAPSPTH12','SNAPSPTH17','PCH_SNAPSPTH_12_17','WICS11','WICS16','PCH_WICS_11_16','WICSPTH11','WICSPTH16','PCH_WICSPTH_11_16']

stores=stores.drop(columns=stores_drop)

# %%
dfs=[county,access,stores,restaurants,insecurity,local,socioeconomic]

df= reduce(lambda left,right: pd.merge(left,right,on=['FIPS']), dfs)
df
# Out:
#        FIPS           County_x   State_x  2010_Census_Population  \
# 0      1001     Autauga County   Alabama                   54571
# 1      1003     Baldwin County   Alabama                  182265
# 2      1005     Barbour County   Alabama                   27457
# 3      1007        Bibb County   Alabama                   22915
# 4      1009      Blount County   Alabama                   57322
# ...     ...                ...       ...                     ...
# 3135  56037  Sweetwater County   Wyoming                   43806
# 3136  56039       Teton County   Wyoming                   21294
# 3137  56041       Uinta County   Wyoming                   21118
# 3138  56043    Washakie County   Wyoming                    8533
# 3139  56045      Weston County   Wyoming                    7208
#
#       Population_Estimate_2011  Population_Estimate_2012  \
# 0                        55208                     54936
# 1                       186540                    190143
# 2                        27350                     27174
# 3                        22747                     22664
# 4                        57554                     57570
# ...                        ...                       ...
# 3135                     43981                     45005
# 3136                     21414                     21625
# 3137                     20893                     20994
# 3138                      8448                      8408
# 3139                      7142                      7077
#
#       Population_Estimate_2013  Population_Estimate_2014  \
# 0                        54713                     54876
# 1                       194886                    199189
# 2                        26944                     26758
# 3                        22516                     22541
# 4                        57611                     57521
# ...                        ...                       ...
# 3135                     45162                     44957
# 3136                     22318                     22777
# 3137                     20953                     20827
# 3138                      8414                      8275
# 3139                      7137                      7138
#
#       Population_Estimate_2015 State_y  ... PCT_NHPI10  PCT_65OLDER10  \
# 0                        54838      AL  ...   0.040314      11.995382
# 1                       202995      AL  ...   0.043343      16.771185
# 2                        26294      AL  ...   0.087409      14.236807
# 3                        22562      AL  ...   0.030548      12.681650
# 4                        57522      AL  ...   0.031402      14.722096
# ...                        ...     ...  ...        ...            ...
# 3135                     44754      WY  ...   0.093594       8.316212
# 3136                     23016      WY  ...   0.061050       9.852541
# 3137                     20770      WY  ...   0.161000       8.873946
# 3138                      8280      WY  ...   0.011719      17.672565
# 3139                      7197      WY  ...   0.027747      15.940622
#
#       PCT_18YOUNGER10  MEDHHINC15  POVRATE15  PERPOV10  CHILDPOVRATE15  \
# 0           26.777959     56580.0       12.7         0            18.8
# 1           22.987408     52387.0       12.9         0            19.6
# 2           21.906982     31433.0       32.0         1            45.2
# 3           22.696923     40767.0       22.2         0            29.3
# 4           24.608353     50487.0       14.7         0            22.2
# ...               ...         ...        ...       ...             ...
# 3135        27.094462     71867.0        8.5         0            10.2
# 3136        19.141542     83290.0        6.6         0             7.6
# 3137        30.168577     62968.0        9.8         0            11.9
# 3138        25.454119     56088.0       11.2         0            15.7
# 3139        21.822974     60986.0        9.8         0            13.1
#
#       PERCHLDPOV10  METRO13  POPLOSS10
# 0                0        1        0.0
# 1                0        1        0.0
# 2                1        0        0.0
# 3                1        1        0.0
# 4                0        1        0.0
# ...            ...      ...        ...
# 3135             0        0        0.0
# 3136             0        0        0.0
# 3137             0        0        0.0
# 3138             0        0        0.0
# 3139             0        0        0.0
#
# [3140 rows x 196 columns]

# %%
df = df.loc[:,~df.columns.duplicated()]
df
# Out:
#        FIPS           County_x   State_x  2010_Census_Population  \
# 0      1001     Autauga County   Alabama                   54571
# 1      1003     Baldwin County   Alabama                  182265
# 2      1005     Barbour County   Alabama                   27457
# 3      1007        Bibb County   Alabama                   22915
# 4      1009      Blount County   Alabama                   57322
# ...     ...                ...       ...                     ...
# 3135  56037  Sweetwater County   Wyoming                   43806
# 3136  56039       Teton County   Wyoming                   21294
# 3137  56041       Uinta County   Wyoming                   21118
# 3138  56043    Washakie County   Wyoming                    8533
# 3139  56045      Weston County   Wyoming                    7208
#
#       Population_Estimate_2011  Population_Estimate_2012  \
# 0                        55208                     54936
# 1                       186540                    190143
# 2                        27350                     27174
# 3                        22747                     22664
# 4                        57554                     57570
# ...                        ...                       ...
# 3135                     43981                     45005
# 3136                     21414                     21625
# 3137                     20893                     20994
# 3138                      8448                      8408
# 3139                      7142                      7077
#
#       Population_Estimate_2013  Population_Estimate_2014  \
# 0                        54713                     54876
# 1                       194886                    199189
# 2                        26944                     26758
# 3                        22516                     22541
# 4                        57611                     57521
# ...                        ...                       ...
# 3135                     45162                     44957
# 3136                     22318                     22777
# 3137                     20953                     20827
# 3138                      8414                      8275
# 3139                      7137                      7138
#
#       Population_Estimate_2015 State_y  ... PCT_NHPI10  PCT_65OLDER10  \
# 0                        54838      AL  ...   0.040314      11.995382
# 1                       202995      AL  ...   0.043343      16.771185
# 2                        26294      AL  ...   0.087409      14.236807
# 3                        22562      AL  ...   0.030548      12.681650
# 4                        57522      AL  ...   0.031402      14.722096
# ...                        ...     ...  ...        ...            ...
# 3135                     44754      WY  ...   0.093594       8.316212
# 3136                     23016      WY  ...   0.061050       9.852541
# 3137                     20770      WY  ...   0.161000       8.873946
# 3138                      8280      WY  ...   0.011719      17.672565
# 3139                      7197      WY  ...   0.027747      15.940622
#
#       PCT_18YOUNGER10  MEDHHINC15  POVRATE15  PERPOV10  CHILDPOVRATE15  \
# 0           26.777959     56580.0       12.7         0            18.8
# 1           22.987408     52387.0       12.9         0            19.6
# 2           21.906982     31433.0       32.0         1            45.2
# 3           22.696923     40767.0       22.2         0            29.3
# 4           24.608353     50487.0       14.7         0            22.2
# ...               ...         ...        ...       ...             ...
# 3135        27.094462     71867.0        8.5         0            10.2
# 3136        19.141542     83290.0        6.6         0             7.6
# 3137        30.168577     62968.0        9.8         0            11.9
# 3138        25.454119     56088.0       11.2         0            15.7
# 3139        21.822974     60986.0        9.8         0            13.1
#
#       PERCHLDPOV10  METRO13  POPLOSS10
# 0                0        1        0.0
# 1                0        1        0.0
# 2                1        0        0.0
# 3                1        1        0.0
# 4                0        1        0.0
# ...            ...      ...        ...
# 3135             0        0        0.0
# 3136             0        0        0.0
# 3137             0        0        0.0
# 3138             0        0        0.0
# 3139             0        0        0.0
#
# [3140 rows x 188 columns]

# %%
df = df.drop(columns=['State_y','County_y','County','State'])

# %%
df.to_csv('food_access.csv')
